# %%
# importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# importing files

# %%
df=pd.read_csv(r"C:\Users\Bn Maliq\Desktop\mydataset\Insurance Premium Prediction Dataset.csv")
df.head(15)
# Out:
#      Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 0   56.0    Male        99990.0        Married                   1.0
# 1   46.0    Male         2867.0         Single                   1.0
# 2   32.0  Female        30154.0       Divorced                   3.0
# 3   60.0  Female        48371.0       Divorced                   0.0
# 4   25.0  Female        54174.0       Divorced                   0.0
# 5   38.0    Male        31769.0        Married                   1.0
# 6   56.0  Female        26209.0         Single                   1.0
# 7   36.0    Male         8762.0         Single                   3.0
# 8   40.0    Male        29471.0         Single                   4.0
# 9   28.0    Male        94317.0        Married                   3.0
# 10  28.0  Female        86211.0        Married                   4.0
# 11  41.0  Female        36427.0         Single                   2.0
# 12   NaN  Female        26626.0        Married                   NaN
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Annual Income', 'Marital Status',
#        'Number of Dependents', 'Education Level', 'Occupation', 'Health Score',
#        'Location', 'Policy Type', 'Previous Claims', 'Vehicle Age',
#        'Credit Score', 'Insurance Duration', 'Premium Amount',
#        'Policy Start Date', 'Customer Feedback', 'Smoking Status',
#        'Exercise Frequency', 'Property Type'],
#       dtype='object')

# %%
df.shape
# Out:
# (278860, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278860 entries, 0 to 278859
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Age                   274175 non-null  float64
#  1   Gender                278860 non-null  object
#  2   Annual Income         264905 non-null  float64
#  3   Marital Status        273841 non-null  object
#  4   Number of Dependents  250974 non-null  float64
#  5   Education Level       278860 non-null  object
#  6   Occupation            197572 non-null  object
#  7   Health Score          268263 non-null  float64
#  8   Location              278860 non-null  object
#  9   Policy Type           278860 non-null  object
#  10  Previous Claims       197572 non-null  float64
#  11  Vehicle Age           278860 non-null  int64
#  12  Credit Score          250974 non-null  float64
#  13  Insurance Duration    278860 non-null  int64
# ...

# %%
# checking for null value

# %%
df.isnull().sum()
# Out:
# Age                      4685
# Gender                      0
# Annual Income           13955
# Marital Status           5019
# Number of Dependents    27886
# Education Level             0
# Occupation              81288
# Health Score            10597
# Location                    0
# Policy Type                 0
# Previous Claims         81288
# Vehicle Age                 0
# Credit Score            27886
# Insurance Duration          0
# Premium Amount           1841
# Policy Start Date           0
# Customer Feedback       18349
# Smoking Status              0
# Exercise Frequency          0
# Property Type               0
# dtype: int64

# %%
# checking for percentage of null values

# %%
df.isnull().sum()/len(df.index)*100
# Out:
# Age                      1.680055
# Gender                   0.000000
# Annual Income            5.004303
# Marital Status           1.799828
# Number of Dependents    10.000000
# Education Level          0.000000
# Occupation              29.150111
# Health Score             3.800115
# Location                 0.000000
# Policy Type              0.000000
# Previous Claims         29.150111
# Vehicle Age              0.000000
# Credit Score            10.000000
# Insurance Duration       0.000000
# Premium Amount           0.660188
# Policy Start Date        0.000000
# Customer Feedback        6.580004
# Smoking Status           0.000000
# Exercise Frequency       0.000000
# Property Type            0.000000
# dtype: float64

# %%
# dropping column not necessary

# %%
df.drop("Customer Feedback", axis=1,inplace=True)

# %%
df.head()
# Out:
#     Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 0  56.0    Male        99990.0        Married                   1.0
# 1  46.0    Male         2867.0         Single                   1.0
# 2  32.0  Female        30154.0       Divorced                   3.0
# 3  60.0  Female        48371.0       Divorced                   0.0
# 4  25.0  Female        54174.0       Divorced                   0.0
#
#   Education Level     Occupation  Health Score  Location    Policy Type  \
# 0        Master's            NaN     31.074627     Urban  Comprehensive
# 1      Bachelor's            NaN     50.271335     Urban  Comprehensive
# 2      Bachelor's            NaN     14.714909  Suburban  Comprehensive
# 3             PhD  Self-Employed     25.346926     Rural  Comprehensive
# 4     High School  Self-Employed      6.659499     Urban  Comprehensive
#
#    Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# ...

# %%
# droping unncessary column

# %%
df.drop("Policy Start Date", axis=1,inplace=True)

# %%
# dropping the Dependents column

# %%
df.drop("Number of Dependents", axis=1,inplace=True)

# %%
# dropping occupation column

# %%
# checking if it has been removed

# %%
df.drop("Occupation", axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Annual Income', 'Marital Status', 'Education Level',
#        'Health Score', 'Location', 'Policy Type', 'Previous Claims',
#        'Vehicle Age', 'Credit Score', 'Insurance Duration', 'Premium Amount',
#        'Smoking Status', 'Exercise Frequency', 'Property Type'],
#       dtype='object')

# %%
# checking for the null values agains

# %%
df.isnull().sum()
# Out:
# Age                    4685
# Gender                    0
# Annual Income         13955
# Marital Status         5019
# Education Level           0
# Health Score          10597
# Location                  0
# Policy Type               0
# Previous Claims       81288
# Vehicle Age               0
# Credit Score          27886
# Insurance Duration        0
# Premium Amount         1841
# Smoking Status            0
# Exercise Frequency        0
# Property Type             0
# dtype: int64

# %%
# getting information on the age column

# %%
df["Age"].describe()
# Out:
# count    274175.000000
# mean         41.020771
# std          13.549683
# min          18.000000
# 25%          29.000000
# 50%          41.000000
# 75%          53.000000
# max          64.000000
# Name: Age, dtype: float64

# %%
# filling the Age column

# %%
df.loc[:,"Age"]=df["Age"].fillna(df["Age"].mean())

# %%
df["Annual Income"].describe()
# Out:
# count    264905.000000
# mean      42089.085329
# std       35444.517255
# min           0.000000
# 25%       13588.000000
# 50%       32191.000000
# 75%       62164.000000
# max      149997.000000
# Name: Annual Income, dtype: float64

# %%
# filling the annual income

# %%
df.loc[:,"Annual Income"]=df["Annual Income"].fillna(df["Annual Income"].mean())

# %%
df.isnull().sum()
# Out:
# Age                       0
# Gender                    0
# Annual Income             0
# Marital Status         5019
# Education Level           0
# Health Score          10597
# Location                  0
# Policy Type               0
# Previous Claims       81288
# Vehicle Age               0
# Credit Score          27886
# Insurance Duration        0
# Premium Amount         1841
# Smoking Status            0
# Exercise Frequency        0
# Property Type             0
# dtype: int64

# %%
# getting information on the marital status

# %%
df["Marital Status"].describe()
# Out:
# count     273841
# unique         3
# top       Single
# freq       91497
# Name: Marital Status, dtype: object

# %%
df["Marital Status"].unique()
# Out:
# array(['Married', 'Single', 'Divorced', nan], dtype=object)

# %%
# removing the null value in marital status

# %%
df.dropna(subset=["Marital Status"],inplace=True)

# %%
# checking if it has been removed

# %%
df.isnull().sum()
# Out:
# Age                       0
# Gender                    0
# Annual Income             0
# Marital Status            0
# Education Level           0
# Health Score          10406
# Location                  0
# Policy Type               0
# Previous Claims       79783
# Vehicle Age               0
# Credit Score          27388
# Insurance Duration        0
# Premium Amount         1813
# Smoking Status            0
# Exercise Frequency        0
# Property Type             0
# dtype: int64

# %%
df.shape
# Out:
# (273841, 16)

# %%
df.head(20)
# Out:
#           Age  Gender  Annual Income Marital Status Education Level  \
# 0   56.000000    Male        99990.0        Married        Master's
# 1   46.000000    Male         2867.0         Single      Bachelor's
# 2   32.000000  Female        30154.0       Divorced      Bachelor's
# 3   60.000000  Female        48371.0       Divorced             PhD
# 4   25.000000  Female        54174.0       Divorced     High School
# 5   38.000000    Male        31769.0        Married      Bachelor's
# 6   56.000000  Female        26209.0         Single        Master's
# 7   36.000000    Male         8762.0         Single      Bachelor's
# 8   40.000000    Male        29471.0         Single     High School
# 9   28.000000    Male        94317.0        Married     High School
# 10  28.000000  Female        86211.0        Married        Master's
# 11  41.000000  Female        36427.0         Single     High School
# 12  41.020771  Female        26626.0        Married     High School
# ...

# %%
df["Health Score"].describe()
# Out:
# count    263435.000000
# mean         28.584980
# std          15.969586
# min           0.035436
# 25%          16.148252
# 50%          26.443287
# 75%          38.968933
# max          93.876090
# Name: Health Score, dtype: float64

# %%
df[df["Health Score"].isnull()]
# Out:
#          Age  Gender  Annual Income Marital Status Education Level  \
# 68      43.0    Male        82932.0         Single     High School
# 89      58.0    Male        75256.0        Married             PhD
# 100     25.0    Male        69219.0       Divorced     High School
# 111     58.0  Female        10526.0        Married        Master's
# 122     52.0  Female        45348.0         Single        Master's
# ...      ...     ...            ...            ...             ...
# 278683  60.0    Male          445.0        Married             PhD
# 278700  23.0  Female        25404.0         Single     High School
# 278734  61.0  Female         8333.0        Married             PhD
# 278765  46.0  Female         5377.0         Single     High School
# 278776  22.0    Male         9261.0       Divorced             PhD
#
#         Health Score  Location    Policy Type  Previous Claims  Vehicle Age  \
# 68               NaN     Rural          Basic              NaN           17
# ...

# %%
# filling Health Score with mean

# %%
df.loc[:,"Health Score"]=df["Age"].fillna(df["Health Score"].mean())

# %%
# checking it has changed

# %%
df.isnull().sum()/len(df.index)*100
# Out:
# Age                    0.000000
# Gender                 0.000000
# Annual Income          0.000000
# Marital Status         0.000000
# Education Level        0.000000
# Health Score           0.000000
# Location               0.000000
# Policy Type            0.000000
# Previous Claims       29.134790
# Vehicle Age            0.000000
# Credit Score          10.001424
# Insurance Duration     0.000000
# Premium Amount         0.662063
# Smoking Status         0.000000
# Exercise Frequency     0.000000
# Property Type          0.000000
# dtype: float64

# %%
# getting information on Previous Claims

# %%
df["Previous Claims"].mode()
# Out:
# 0    1.0
# Name: Previous Claims, dtype: float64

# %%
df.shape
# Out:
# (273841, 16)

# %%
# dropping the Previous Claims column

# %%
df.drop("Previous Claims", axis=1,inplace=True)

# %%
df.shape
# Out:
# (273841, 15)

# %%
# Getting information on credit score

# %%
df["Credit Score"].describe()
# Out:
# count    246453.000000
# mean        574.411981
# std         158.769005
# min         300.000000
# 25%         437.000000
# 50%         575.000000
# 75%         712.000000
# max         849.000000
# Name: Credit Score, dtype: float64

# %%
# filling the credit score with the mean

# %%
df.loc[:,"Credit Score"]=df["Age"].fillna(df["Credit Score"].mean())

# %%
# checking if it has been filled

# %%
df.isnull().sum()
# Out:
# Age                      0
# Gender                   0
# Annual Income            0
# Marital Status           0
# Education Level          0
# Health Score             0
# Location                 0
# Policy Type              0
# Vehicle Age              0
# Credit Score             0
# Insurance Duration       0
# Premium Amount        1813
# Smoking Status           0
# Exercise Frequency       0
# Property Type            0
# dtype: int64

# %%
# getting information on premium amount

# %%
df["Premium Amount"].describe()
# Out:
# count    272028.00000
# mean        965.80709
# std         909.23867
# min           0.00000
# 25%         286.00000
# 50%         688.00000
# 75%        1366.00000
# max        4999.00000
# Name: Premium Amount, dtype: float64

# %%
# filling it with the mean

# %%
df.loc[:,"Premium Amount"]=df["Age"].fillna(df["Premium Amount"].mean())

# %%
# checking if it has been filled

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Annual Income         0
# Marital Status        0
# Education Level       0
# Health Score          0
# Location              0
# Policy Type           0
# Vehicle Age           0
# Credit Score          0
# Insurance Duration    0
# Premium Amount        0
# Smoking Status        0
# Exercise Frequency    0
# Property Type         0
# dtype: int64

# %% [markdown]
# At this junction we have successfully removed all the null values

# %%
# selecting the categorical and numerical column

# %%
discrete_df = df.select_dtypes(include=['object'])
numerical_df = df.select_dtypes(include=[np.number])

# %%
# Creating function to select only the categorical data

# %%
def discrete_uni_analysis(discrete_data):
    for col_name in discrete_data:
        print('*'*10, col_name, '*'*10)
        print(discrete_data[col_name].agg(['count', 'nunique', 'unique']))
        print('Value counts: \n', discrete_data[col_name].value_counts())
        print()

# %%
# calling the function

# %%
discrete_uni_analysis(discrete_df)
# Out:
# ********** Gender **********
# count              273841
# nunique                 2
# unique     [Male, Female]
# Name: Gender, dtype: object
# Value counts:
#  Gender
# Male      137232
# Female    136609
# Name: count, dtype: int64
#
# ********** Marital Status **********
# count                           273841
# nunique                              3
# unique     [Married, Single, Divorced]
# Name: Marital Status, dtype: object
# Value counts:
#  Marital Status
# Single      91497
# Married     91261
# Divorced    91083
# Name: count, dtype: int64
#
# ********** Education Level **********
# count                                        273841
# nunique                                           4
# unique     [Master's, Bachelor's, PhD, High School]
# Name: Education Level, dtype: object
# Value counts:
#  Education Level
# Bachelor's     68716
# PhD            68672
# Master's       68518
# High School    67935
# Name: count, dtype: int64
#
# ********** Location **********
# ...

# %%
# creating function for numerical analysis

# %%
def num_uni_analysis(numerical_data):
    for col_name in numerical_data:
        print('*'*10, col_name, '*'*10)
        print(numerical_data[col_name].agg(['min', 'max', 'mean', 'median', 'std']))
        print()

# %%
# calling the function

# %%
num_uni_analysis(numerical_df)
# Out:
# ********** Age **********
# min       18.000000
# max       64.000000
# mean      41.021630
# median    41.000000
# std       13.436169
# Name: Age, dtype: float64
#
# ********** Annual Income **********
# min            0.000000
# max       149997.000000
# mean       42082.689700
# median     34661.000000
# std        34543.814718
# Name: Annual Income, dtype: float64
#
# ********** Health Score **********
# min       18.000000
# max       64.000000
# mean      41.021630
# median    41.000000
# std       13.436169
# Name: Health Score, dtype: float64
#
# ********** Vehicle Age **********
# min        0.000000
# max       19.000000
# mean       9.520116
# median    10.000000
# std        5.767453
# Name: Vehicle Age, dtype: float64
#
# ********** Credit Score **********
# min       18.000000
# max       64.000000
# mean      41.021630
# median    41.000000
# std       13.436169
# Name: Credit Score, dtype: float64
#
# ********** Insurance Duration **********
# min       1.000000
# ...

# %%
# checking for outliers in numerical column

# %%
for col in numerical_df:
    plt.figure(figsize=(6, 4))
    sns.boxplot(data=df[col])
    plt.title(f'Box Plot for {col}')
    plt.show()

# %%
for col in numerical_df:
    plt.figure(figsize=(6,4))
    sns.histplot(data=df[col])
    plt.title(f'Hist Plot {col}')
    plt.show()

# %%
def univariate_analysis(numerical_df):
    num_cols = len(numerical_df.columns)
    fig, axes = plt.subplots(nrows=(num_cols // 3) + 1, ncols=3,
                             figsize=(18, 4 * ((num_cols // 3) + 1)))
    fig.tight_layout(pad=5.0)

    axes = axes.flatten()  # Flatten axes array for easy iteration

    for i, col_name in enumerate(numerical_df.columns):
        sns.histplot(data=numerical_df, x=col_name, kde=True, ax=axes[i])
        # Use KDE for a smooth distribution curve
        axes[i].set_title(f'Distribution of {col_name}')
        axes[i].set_xlabel(col_name)
        axes[i].set_ylabel('Frequency')

    # Hide any extra subplots if the number of numeric columns is not a multiple of 3
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    plt.show()

univariate_analysis(numerical_df)

# %%
for col in discrete_df:
    plt.figure(figsize=(6, 4))
    sns.barplot(data=df[col])
    plt.title(f'Box Plot for {col}')
    plt.show()

# %%
gender_counts = df['Gender'].value_counts()

# Bar plot for Region
plt.figure(figsize=(10, 6))
sns.barplot(y=gender_counts.index, x=gender_counts.values)
plt.title("Frequency of Regions")
plt.ylabel("Region")
plt.xlabel("Count")
plt.show()

# %%
df.head()
# Out:
#     Age  Gender  Annual Income Marital Status Education Level  Health Score  \
# 0  56.0    Male        99990.0        Married        Master's          56.0
# 1  46.0    Male         2867.0         Single      Bachelor's          46.0
# 2  32.0  Female        30154.0       Divorced      Bachelor's          32.0
# 3  60.0  Female        48371.0       Divorced             PhD          60.0
# 4  25.0  Female        54174.0       Divorced     High School          25.0
#
#    Location    Policy Type  Vehicle Age  Credit Score  Insurance Duration  \
# 0     Urban  Comprehensive           13          56.0                   5
# 1     Urban  Comprehensive            3          46.0                   4
# 2  Suburban  Comprehensive           16          32.0                   8
# 3     Rural  Comprehensive           11          60.0                   7
# 4     Urban  Comprehensive            9          25.0                   8
#
# ...

# %%
# Bivariate Analysis

# %%
# Correlation calculation
correlation = df['Credit Score'].corr(df['Premium Amount'])
print(f"Correlation between Credit and Premium Amount: {correlation}")

# Scatter plot with regression line
sns.regplot(x='Credit Score', y='Premium Amount', data=df)
plt.title("Credit Score Vs Premium Amount")
plt.xlabel("Credit Score")
plt.ylabel("Premium Amount")
plt.show()
# Out:
# Correlation between Credit and Premium Amount: 0.9999999999999999

# %%
# Correlation calculation
correlation = df['Health Score'].corr(df['Premium Amount'])
print(f"Correlation between Health Score and Premium Amount: {correlation}")

# Scatter plot with regression line
sns.regplot(x='Health Score', y='Premium Amount', data=df)
plt.title("Credit Score Vs Premium Amount")
plt.xlabel("Health Score")
plt.ylabel("Premium Amount")
plt.show()
# Out:
# Correlation between Health Score and Premium Amount: 0.9999999999999999

# %%
# Correlation calculation
correlation = df["Vehicle Age"].corr(df['Premium Amount'])
print(f"Correlation between Vehicle Age and Premium Amount: {correlation}")

# Scatter plot with regression line
sns.regplot(x="Vehicle Age", y='Premium Amount', data=df)
plt.title("Vehicle Age Vs Premium Amount")
plt.xlabel("Vehicle Age")
plt.ylabel("Premium Amount")
plt.show()
# Out:
# Correlation between Vehicle Age and Premium Amount: 0.0009996880772382944

# %%
# Correlation calculation
correlation = df["Insurance Duration"].corr(df['Premium Amount'])
print(f"Correlation between Insurance Duration and Premium Amount: {correlation}")

# Scatter plot with regression line
sns.regplot(x="Insurance Duration", y='Premium Amount', data=df)
plt.title("Insurance Duration Vs Premium Amount")
plt.xlabel("Insurance Duration")
plt.ylabel("Premium Amount")
plt.show()
# Out:
# Correlation between Insurance Duration and Premium Amount: 0.00011389472165713618

# %%
# Correlation calculation
correlation = df["Age"].corr(df['Premium Amount'])
print(f"Correlation between  Age and Premium Amount: {correlation}")

# Scatter plot with regression line
sns.regplot(x="Age", y='Premium Amount', data=df)
plt.title("Age Vs Premium Amount")
plt.xlabel(" Age")
plt.ylabel("Premium Amount")
plt.show()
# Out:
# Correlation between  Age and Premium Amount: 0.9999999999999999

# %%
# Machine Learning Path

# %%
# segregage input and output

# %%
x=df.drop(columns=["Premium Amount"])
y=df["Premium Amount"]

# %%
# Splitting Data Into Train and Test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, random_state=0)
print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (205380, 14) (68461, 14)
# (205380,) (68461,)

# %%
# Apply data preparation on training data

# %%
x_train_cat=x_train.select_dtypes(include=["object"])
x_train_num=x_train.select_dtypes(include=["number"])

# %%
x_train_cat.head()
# Out:
#         Gender Marital Status Education Level  Location    Policy Type  \
# 129339    Male       Divorced      Bachelor's  Suburban  Comprehensive
# 102799  Female         Single      Bachelor's  Suburban        Premium
# 117723    Male        Married      Bachelor's  Suburban  Comprehensive
# 14388   Female         Single        Master's     Rural          Basic
# 162782  Female         Single     High School     Urban          Basic
#
#        Smoking Status Exercise Frequency Property Type
# 129339             No            Monthly         Condo
# 102799             No              Daily         Condo
# 117723            Yes             Rarely     Apartment
# 14388             Yes            Monthly         Condo
# 162782            Yes             Rarely         House

# %%
x_train_num.head()
# Out:
#          Age  Annual Income  Health Score  Vehicle Age  Credit Score  \
# 129339  49.0         9252.0          49.0            8          49.0
# 102799  19.0        63123.0          19.0            1          19.0
# 117723  24.0        16260.0          24.0            2          24.0
# 14388   36.0        10713.0          36.0           19          36.0
# 162782  49.0        39036.0          49.0            4          49.0
#
#         Insurance Duration
# 129339                   6
# 102799                   7
# 117723                   2
# 14388                    2
# 162782                   1

# %%
# using standardization for scalling

# %%
from sklearn.preprocessing import StandardScaler
std_scaler=StandardScaler()
# After rescaling, column names are lost since data frame are converted to numpy ndarrya
x_train_num_transformed=pd.DataFrame(std_scaler.fit_transform(x_train_num), 
                                     columns=std_scaler.get_feature_names_out(), 
                                     index=x_train_num.index)
x_train_num_transformed.describe()
# Out:
#                 Age  Annual Income  Health Score   Vehicle Age  Credit Score  \
# count  2.053800e+05   2.053800e+05  2.053800e+05  2.053800e+05  2.053800e+05
# mean  -1.444404e-17   2.928593e-17 -1.444404e-17 -5.416081e-17 -1.444404e-17
# std    1.000002e+00   1.000002e+00  1.000002e+00  1.000002e+00  1.000002e+00
# min   -1.711082e+00  -1.218232e+00 -1.711082e+00 -1.649689e+00 -1.711082e+00
# 25%   -8.923920e-01  -8.014824e-01 -8.923920e-01 -7.829993e-01 -8.923920e-01
# 50%    7.245806e-04  -2.148337e-01  7.245806e-04  8.369056e-02  7.245806e-04
# 75%    8.938412e-01   5.208710e-01  8.938412e-01  9.503805e-01  8.938412e-01
# max    1.712531e+00   3.121013e+00  1.712531e+00  1.643732e+00  1.712531e+00
#
#        Insurance Duration
# count        2.053800e+05
# mean         3.895565e-17
# std          1.000002e+00
# min         -1.551882e+00
# 25%         -7.773845e-01
# 50%         -2.886737e-03
# 75%          7.716111e-01
# max          1.546109e+00

# %%
# for categorical variable

# %%
x_train_cat.head()
# Out:
#         Gender Marital Status Education Level  Location    Policy Type  \
# 129339    Male       Divorced      Bachelor's  Suburban  Comprehensive
# 102799  Female         Single      Bachelor's  Suburban        Premium
# 117723    Male        Married      Bachelor's  Suburban  Comprehensive
# 14388   Female         Single        Master's     Rural          Basic
# 162782  Female         Single     High School     Urban          Basic
#
#        Smoking Status Exercise Frequency Property Type
# 129339             No            Monthly         Condo
# 102799             No              Daily         Condo
# 117723            Yes             Rarely     Apartment
# 14388             Yes            Monthly         Condo
# 162782            Yes             Rarely         House

# %%
# defining order for categorical column
gender_cat=["Male", "Female"]
marital_status_Cat=["Single","Divorced","Married"]
education_cat=["PhD","Master's", "Bachelor's",  "High School"]
location_cat=['Urban', 'Suburban', 'Rural']
policy_type_cat=['Comprehensive', 'Premium', 'Basic']
smoking_cat=['Yes', 'No']
excercise_cat=['Daily', 'Weekly', 'Monthly', 'Rarely']
property_cat=['Condo', 'House', 'Apartment']

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ordinal_encoder=OrdinalEncoder(categories=[gender_cat, marital_status_Cat, education_cat, location_cat, 
                                           policy_type_cat, smoking_cat, excercise_cat, property_cat],
                                           handle_unknown="use_encoded_value", unknown_value=-1,
                                           encoded_missing_value=-5)

# %%
# Applying the encoder

# %%
x_train_cat_transformed=pd.DataFrame(ordinal_encoder.fit_transform(x_train_cat),
                                     columns=ordinal_encoder.get_feature_names_out(),
                                     index=x_train_cat.index)

# %%
x_train_cat_transformed.head()
# Out:
#         Gender  Marital Status  Education Level  Location  Policy Type  \
# 129339     0.0             1.0              2.0       1.0          0.0
# 102799     1.0             0.0              2.0       1.0          1.0
# 117723     0.0             2.0              2.0       1.0          0.0
# 14388      1.0             0.0              1.0       2.0          2.0
# 162782     1.0             0.0              3.0       0.0          2.0
#
#         Smoking Status  Exercise Frequency  Property Type
# 129339             1.0                 2.0            0.0
# 102799             1.0                 0.0            0.0
# 117723             0.0                 3.0            2.0
# 14388              0.0                 2.0            0.0
# 162782             0.0                 3.0            1.0

# %%
# concatenate x_train_cat_transformed and x_train_num_transformed
x_train_transformed=pd.concat([x_train_num_transformed, x_train_cat_transformed], axis=1)

# %%
x_train_transformed.head(10)
# Out:
#              Age  Annual Income  Health Score  Vehicle Age  Credit Score  \
# 129339  0.596136      -0.950582      0.596136    -0.262985      0.596136
# 102799 -1.636656       0.607846     -1.636656    -1.476351     -1.636656
# 117723 -1.264524      -0.747848     -1.264524    -1.303013     -1.264524
# 14388  -0.371407      -0.908317     -0.371407     1.643732     -0.371407
# 162782  0.596136      -0.088964      0.596136    -0.956337      0.596136
# 16059  -0.966818      -0.853294     -0.966818     0.603704     -0.966818
# 174408  0.075151      -0.494923      0.075151    -0.436323      0.075151
# 74094  -1.264524      -0.690280     -1.264524    -1.649689     -1.264524
# 142418  1.042694      -0.673906      1.042694    -1.303013      1.042694
# 41830   1.563679       2.938703      1.563679    -0.262985      1.563679
#
#         Insurance Duration  Gender  Marital Status  Education Level  Location  \
# 129339            0.384362     0.0             1.0              2.0       1.0
# ...

# %%
# applying data preparation on a test data

# %%
x_test_cat=x_train.select_dtypes(include=["object"])
x_test_num=x_train.select_dtypes(include=["number"])

# %%
x_test_cat.head()
# Out:
#         Gender Marital Status Education Level  Location    Policy Type  \
# 129339    Male       Divorced      Bachelor's  Suburban  Comprehensive
# 102799  Female         Single      Bachelor's  Suburban        Premium
# 117723    Male        Married      Bachelor's  Suburban  Comprehensive
# 14388   Female         Single        Master's     Rural          Basic
# 162782  Female         Single     High School     Urban          Basic
#
#        Smoking Status Exercise Frequency Property Type
# 129339             No            Monthly         Condo
# 102799             No              Daily         Condo
# 117723            Yes             Rarely     Apartment
# 14388             Yes            Monthly         Condo
# 162782            Yes             Rarely         House

# %%
x_test_num.head()
# Out:
#          Age  Annual Income  Health Score  Vehicle Age  Credit Score  \
# 129339  49.0         9252.0          49.0            8          49.0
# 102799  19.0        63123.0          19.0            1          19.0
# 117723  24.0        16260.0          24.0            2          24.0
# 14388   36.0        10713.0          36.0           19          36.0
# 162782  49.0        39036.0          49.0            4          49.0
#
#         Insurance Duration
# 129339                   6
# 102799                   7
# 117723                   2
# 14388                    2
# 162782                   1

# %%
# using standardization for scalling

# %%
from sklearn.preprocessing import StandardScaler
std_scaler=StandardScaler()
# After rescaling, column names are lost since data frame are converted to numpy ndarrya
x_test_num_transformed=pd.DataFrame(std_scaler.fit_transform(x_test_num), 
                                     columns=std_scaler.get_feature_names_out(), 
                                     index=x_test_num.index)
x_test_num_transformed.describe()
# Out:
#                 Age  Annual Income  Health Score   Vehicle Age  Credit Score  \
# count  2.053800e+05   2.053800e+05  2.053800e+05  2.053800e+05  2.053800e+05
# mean  -1.444404e-17   2.928593e-17 -1.444404e-17 -5.416081e-17 -1.444404e-17
# std    1.000002e+00   1.000002e+00  1.000002e+00  1.000002e+00  1.000002e+00
# min   -1.711082e+00  -1.218232e+00 -1.711082e+00 -1.649689e+00 -1.711082e+00
# 25%   -8.923920e-01  -8.014824e-01 -8.923920e-01 -7.829993e-01 -8.923920e-01
# 50%    7.245806e-04  -2.148337e-01  7.245806e-04  8.369056e-02  7.245806e-04
# 75%    8.938412e-01   5.208710e-01  8.938412e-01  9.503805e-01  8.938412e-01
# max    1.712531e+00   3.121013e+00  1.712531e+00  1.643732e+00  1.712531e+00
#
#        Insurance Duration
# count        2.053800e+05
# mean         3.895565e-17
# std          1.000002e+00
# min         -1.551882e+00
# 25%         -7.773845e-01
# 50%         -2.886737e-03
# 75%          7.716111e-01
# max          1.546109e+00

# %%
# for categorical variable

# %%
x_test_cat.head()
# Out:
#         Gender Marital Status Education Level  Location    Policy Type  \
# 129339    Male       Divorced      Bachelor's  Suburban  Comprehensive
# 102799  Female         Single      Bachelor's  Suburban        Premium
# 117723    Male        Married      Bachelor's  Suburban  Comprehensive
# 14388   Female         Single        Master's     Rural          Basic
# 162782  Female         Single     High School     Urban          Basic
#
#        Smoking Status Exercise Frequency Property Type
# 129339             No            Monthly         Condo
# 102799             No              Daily         Condo
# 117723            Yes             Rarely     Apartment
# 14388             Yes            Monthly         Condo
# 162782            Yes             Rarely         House

# %%
# defining order for categorical column
gender_cat=["Male", "Female"]
marital_status_Cat=["Single","Divorced","Married"]
education_cat=["PhD","Master's", "Bachelor's",  "High School"]
location_cat=['Urban', 'Suburban', 'Rural']
policy_type_cat=['Comprehensive', 'Premium', 'Basic']
smoking_cat=['Yes', 'No']
excercise_cat=['Daily', 'Weekly', 'Monthly', 'Rarely']
property_cat=['Condo', 'House', 'Apartment']

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ordinal_encoder=OrdinalEncoder(categories=[gender_cat, marital_status_Cat, education_cat, location_cat, 
                                           policy_type_cat, smoking_cat, excercise_cat, property_cat],
                                           handle_unknown="use_encoded_value", unknown_value=-1,
                                           encoded_missing_value=-5)

# %%
# applying the encoder

# %%
x_test_cat_transformed=pd.DataFrame(ordinal_encoder.fit_transform(x_test_cat),
                                     columns=ordinal_encoder.get_feature_names_out(),
                                     index=x_test_cat.index)

# %%
x_test_cat_transformed.describe()
# Out:
#               Gender  Marital Status  Education Level       Location  \
# count  205380.000000   205380.000000    205380.000000  205380.000000
# mean        0.499567        0.999732         1.498023       1.000575
# std         0.500001        0.816698         1.116571       0.815520
# min         0.000000        0.000000         0.000000       0.000000
# 25%         0.000000        0.000000         1.000000       0.000000
# 50%         0.000000        1.000000         1.000000       1.000000
# 75%         1.000000        2.000000         2.000000       2.000000
# max         1.000000        2.000000         3.000000       2.000000
#
#          Policy Type  Smoking Status  Exercise Frequency  Property Type
# count  205380.000000   205380.000000       205380.000000  205380.000000
# mean        1.003048        0.499435            1.501246       1.001709
# std         0.814774        0.500001            1.117091       0.816130
# ...

# %%
# concatenate x_test_cat_transformed and x_test_num_transformed
x_test_transformed=pd.concat([x_test_num_transformed, x_test_cat_transformed], axis=1)

# %%
x_test_transformed.head()
# Out:
#              Age  Annual Income  Health Score  Vehicle Age  Credit Score  \
# 129339  0.596136      -0.950582      0.596136    -0.262985      0.596136
# 102799 -1.636656       0.607846     -1.636656    -1.476351     -1.636656
# 117723 -1.264524      -0.747848     -1.264524    -1.303013     -1.264524
# 14388  -0.371407      -0.908317     -0.371407     1.643732     -0.371407
# 162782  0.596136      -0.088964      0.596136    -0.956337      0.596136
#
#         Insurance Duration  Gender  Marital Status  Education Level  Location  \
# 129339            0.384362     0.0             1.0              2.0       1.0
# 102799            0.771611     1.0             0.0              2.0       1.0
# 117723           -1.164633     0.0             2.0              2.0       1.0
# 14388            -1.164633     1.0             0.0              1.0       2.0
# 162782           -1.551882     1.0             0.0              3.0       0.0
#
# ...

# %%
# training and testing phase

# %%
# %%time
from sklearn.linear_model import LinearRegression
from sklearn import metrics 
LR_regressor = LinearRegression()
from sklearn.metrics import mean_squared_error

LR_regressor.fit(x_train_transformed, y_train)

# y_test_pred=LR_regressor.predict(x_test_transformed)
y_test_pred = LR_regressor.predict(x_test_transformed[:len(y_test)])



LR_MAE=metrics.mean_absolute_error(y_test, y_test_pred)

print("Model's Error: ", LR_MAE)

rms=mean_squared_error(y_test, y_test_pred)
print("Root Mean Square: ", rms)
# Out:
# Model's Error:  15.46226015229033
# Root Mean Square:  358.57713353447195
# CPU times: total: 562 ms
# Wall time: 486 ms

# %%
# print("x_train shape: ", x_train.shape)
# print("x_test shape: ", x_test.shape)
# print("y_train shape: ", y_train.shape)
# print("y_test shape: ", y_test.shape)
# print("x_train_transformed shape: ", x_train_transformed.shape)
# print("x_test_transformed shape: ", x_test_transformed.shape)
# print("y_test shape: ", y_test.shape)
# print("y_test_pred shape: ", y_test_pred.shape)

# %%
output_df = pd.DataFrame({"Actual": y_test.squeeze(), "LR prediction": y_test_pred.squeeze()})
output_df.head(40)

# %%
# Using KNN regression

# %%
# %%time
from sklearn.neighbors import KNeighborsRegressor
from sklearn import metrics

KNN_regressor = KNeighborsRegressor(n_neighbors=5)
print("Fitting KNN regressor...")
KNN_regressor.fit(x_train_transformed, y_train)
print("Making predictions...")
y_test_predknn = KNN_regressor.predict(x_test_transformed[:len(y_test)])
print("Calculating MAE...")
KNN_MAE = metrics.mean_absolute_error(y_test, y_test_predknn)
print("Model's Error (MAE): ", KNN_MAE)

rms=mean_squared_error(y_test, y_test_predknn)
print("Root Mean Square: ", rms)
# Out:
# Fitting KNN regressor...
# Making predictions...
# Calculating MAE...
# Model's Error (MAE):  15.248637789379831
# Root Mean Square:  348.4509215136734
# CPU times: total: 1min 15s
# Wall time: 1min 17s

# %%
# Using Decision Tree

# %%
# %%time 
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics
DT_regressor = DecisionTreeRegressor()
print("Fitting Decision Tree regressor...")
DT_regressor.fit(x_train_transformed, y_train)
print("Making predictions...")
y_test_pred = DT_regressor.predict(x_test_transformed[:len(y_test)])
# y_test_pred = DT_regressor.predict(x_test_transformed)
print("Calculating MAE...")
DT_MAE = metrics.mean_absolute_error(y_test, y_test_pred)
print("Model's Error (MAE): ", DT_MAE)

# %%
# using Random Forex

# %%
# %%time 
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.metrics import r2_score
RF_regressor=RandomForestRegressor()
print("Fitting Fandom Forex regressor...")
RF_regressor.fit(x_train_transformed, y_train)
print("Making predictions...")
y_test_predrf = RF_regressor.predict(x_test_transformed[:len(y_test)])

print("Calculating MAE...")
RF_MAE = metrics.mean_absolute_error(y_test, y_test_predrf)
print("Model's Error (MAE): ", RF_MAE)

rms=mean_squared_error(y_test, y_test_predrf)
print("Root Mean Square: ", rms)
r2=r2_score(y_test, y_test_pred)
print("r2: ", r2)
# Out:
# Fitting Fandom Forex regressor...
# Making predictions...
# Calculating MAE...
# Model's Error (MAE):  15.462260152290337
# Root Mean Square:  358.57713353447224
# r2:  -0.9302395019807321
# CPU times: total: 1min 9s
# Wall time: 1min 12s

# %% [markdown]
# A this junction we found out that Linear regression has less cpu time and less error:
# Model's Error:  15.46226015229033
# CPU times: total: 641 ms
# Wall time: 746 ms

# %%
y_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 68461 entries, 111213 to 164945
# Series name: Premium Amount
# Non-Null Count  Dtype
# --------------  -----
# 68461 non-null  float64
# dtypes: float64(1)
# memory usage: 1.0 MB
