# %%
# importing my libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# importing the file

# %%
df=pd.read_csv(r"C:\Users\Bn Maliq\Desktop\mydataset\fake.csv")

# %%
# getting insight in the data

# %%
df.head()
# Out:
#                                        uuid  ord_in_thread  \
# 0  6a175f46bcd24d39b3e962ad0f29936721db70db              0
# 1  2bdc29d12605ef9cf3f09f9875040a7113be5d5b              0
# 2  c70e149fdd53de5e61c29281100b9de0ed268bc3              0
# 3  7cf7c15731ac2a116dd7f629bd57ea468ed70284              0
# 4  0206b54719c7e241ffe0ad4315b808290dbe6c0f              0
#
#                  author                      published  \
# 0     Barracuda Brigade  2016-10-26T21:41:00.000+03:00
# 1  reasoning with facts  2016-10-29T08:47:11.259+03:00
# 2     Barracuda Brigade  2016-10-31T01:41:49.479+02:00
# 3                Fed Up  2016-11-01T05:22:00.000+02:00
# 4                Fed Up  2016-11-01T21:56:00.000+02:00
#
#                                                title  \
# 0  Muslims BUSTED: They Stole Millions In Gov’t B...
# 1  Re: Why Did Attorney General Loretta Lynch Ple...
# 2  BREAKING: Weiner Cooperating With FBI On Hilla...
# 3  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...
# ...

# %%
# getting information on the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12999 entries, 0 to 12998
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   uuid                12999 non-null  object
#  1   ord_in_thread       12999 non-null  int64
#  2   author              10575 non-null  object
#  3   published           12999 non-null  object
#  4   title               12319 non-null  object
#  5   text                12953 non-null  object
#  6   language            12999 non-null  object
#  7   crawled             12999 non-null  object
#  8   site_url            12999 non-null  object
#  9   country             12823 non-null  object
#  10  domain_rank         8776 non-null   float64
#  11  thread_title        12987 non-null  object
#  12  spam_score          12999 non-null  float64
#  13  main_img_url        9356 non-null   object
#  14  replies_count       12999 non-null  int64
# ...

# %%
# getting idea on the shape of the data

# %%
df.shape
# Out:
# (12999, 20)

# %%
# getting information  on the numerical data

# %%
df.describe()
# Out:
#        ord_in_thread   domain_rank    spam_score  replies_count  \
# count   12999.000000   8776.000000  12999.000000   12999.000000
# mean        0.891530  38092.996582      0.026122       1.383183
# std         6.486822  26825.487454      0.122889       9.656838
# min         0.000000    486.000000      0.000000       0.000000
# 25%         0.000000  17423.000000      0.000000       0.000000
# 50%         0.000000  34478.000000      0.000000       0.000000
# 75%         0.000000  60570.000000      0.000000       0.000000
# max       100.000000  98679.000000      1.000000     309.000000
#
#        participants_count         likes      comments        shares
# count        12999.000000  12999.000000  12999.000000  12999.000000
# mean             1.727518     10.831833      0.038311     10.831833
# std              6.884239     79.798949      0.827335     79.798949
# min              0.000000      0.000000      0.000000      0.000000
# ...

# %%
# getting idea on the columns

# %%
df.columns
# Out:
# Index(['uuid', 'ord_in_thread', 'author', 'published', 'title', 'text',
#        'language', 'crawled', 'site_url', 'country', 'domain_rank',
#        'thread_title', 'spam_score', 'main_img_url', 'replies_count',
#        'participants_count', 'likes', 'comments', 'shares', 'type'],
#       dtype='object')

# %%
# getting information on the null values

# %%
df.isnull().sum()
# Out:
# uuid                     0
# ord_in_thread            0
# author                2424
# published                0
# title                  680
# text                    46
# language                 0
# crawled                  0
# site_url                 0
# country                176
# domain_rank           4223
# thread_title            12
# spam_score               0
# main_img_url          3643
# replies_count            0
# participants_count       0
# likes                    0
# comments                 0
# shares                   0
# type                     0
# dtype: int64

# %%
# getting information on the percentage of the null value

# %%
df.isnull().sum()/len(df.index)*100
# Out:
# uuid                   0.000000
# ord_in_thread          0.000000
# author                18.647588
# published              0.000000
# title                  5.231172
# text                   0.353873
# language               0.000000
# crawled                0.000000
# site_url               0.000000
# country                1.353950
# domain_rank           32.487114
# thread_title           0.092315
# spam_score             0.000000
# main_img_url          28.025233
# replies_count          0.000000
# participants_count     0.000000
# likes                  0.000000
# comments               0.000000
# shares                 0.000000
# type                   0.000000
# dtype: float64

# %%
# getting idea on the order of thread rows

# %%
df[df["ord_in_thread"]>0]
# Out:
#                                            uuid  ord_in_thread  \
# 60     03905a0f06cb711190aad3934af253a0e1c00a83              1
# 61     42c16d3818e64ff4632409cafd309c22df530ac1              2
# 62     336f5dfbea5f263dbdd6ec9be9d1d94d255caa1f              3
# 63     ea086a28e0bbafcd9fbaabd728920337371d4876              4
# 64     6fad6edc4156d92153a9a7a0d66f7ae59b98760c              5
# ...                                         ...            ...
# 12994  f1b5d0e44803f48732bde854a9fdf95837219b12              2
# 12995  36011ceba3647e1bea78299b68b6fb705a1fc1ad              3
# 12996  6995d1aa9ac99926106489b14b5530e85358059a              4
# 12997  7de8ae90eee164eb756db6c8a3772288e11d7a94              5
# 12998  dabef7095b7d9dae6eb0d83c4cbb40b85efd7ae5              6
#
#                    author                      published title  \
# 60              Anonymous  2016-10-26T23:12:00.000+03:00   NaN
# 61              Anonymous  2016-10-26T22:48:00.000+03:00   NaN
# ...

# %%
# getting idea on the type news

# %%
df["published"].value_counts()
# Out:
# published
# 2016-10-27T03:00:00.000+03:00    59
# 2016-10-26T03:00:00.000+03:00    37
# 2016-10-28T03:00:00.000+03:00    34
# 2016-11-01T02:00:00.000+02:00    30
# 2016-10-31T11:00:00.000+02:00    25
#                                  ..
# 2016-11-02T10:35:17.407+02:00     1
# 2016-11-02T09:11:00.000+02:00     1
# 2016-11-02T03:09:00.000+02:00     1
# 2016-11-02T03:06:00.000+02:00     1
# 2016-10-26T23:58:00.000+03:00     1
# Name: count, Length: 11973, dtype: int64

# %%
# checking the information again

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12999 entries, 0 to 12998
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   uuid                12999 non-null  object
#  1   ord_in_thread       12999 non-null  int64
#  2   author              10575 non-null  object
#  3   published           12999 non-null  object
#  4   title               12319 non-null  object
#  5   text                12953 non-null  object
#  6   language            12999 non-null  object
#  7   crawled             12999 non-null  object
#  8   site_url            12999 non-null  object
#  9   country             12823 non-null  object
#  10  domain_rank         8776 non-null   float64
#  11  thread_title        12987 non-null  object
#  12  spam_score          12999 non-null  float64
#  13  main_img_url        9356 non-null   object
#  14  replies_count       12999 non-null  int64
# ...

# %%
# filling the some of the numerical column

# %%
df.loc[:, "domain_rank"]=df["domain_rank"].fillna(df["domain_rank"]).mean()

# %%
df.shape
# Out:
# (12999, 20)

# %%
df["country"].value_counts()
# Out:
# country
# US    10367
# GB      831
# RU      400
# DE      224
# FR      207
# TV      201
# EU      112
# CA      103
# IS      100
# ES      100
# NL       55
# ME       34
# IN       23
# BG       19
# CO       17
# LI       10
# IR        7
# EE        4
# ZA        3
# SG        2
# IO        1
# SE        1
# AU        1
# CH        1
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x="type")
plt.title("Type of misleading news")
plt.show()

# %%
# dropping the numerical column

# %%
df_cat=df.select_dtypes(include=["object"])

# %%
df_cat.head()
# Out:
#                                        uuid                author  \
# 0  6a175f46bcd24d39b3e962ad0f29936721db70db     Barracuda Brigade
# 1  2bdc29d12605ef9cf3f09f9875040a7113be5d5b  reasoning with facts
# 2  c70e149fdd53de5e61c29281100b9de0ed268bc3     Barracuda Brigade
# 3  7cf7c15731ac2a116dd7f629bd57ea468ed70284                Fed Up
# 4  0206b54719c7e241ffe0ad4315b808290dbe6c0f                Fed Up
#
#                        published  \
# 0  2016-10-26T21:41:00.000+03:00
# 1  2016-10-29T08:47:11.259+03:00
# 2  2016-10-31T01:41:49.479+02:00
# 3  2016-11-01T05:22:00.000+02:00
# 4  2016-11-01T21:56:00.000+02:00
#
#                                                title  \
# 0  Muslims BUSTED: They Stole Millions In Gov’t B...
# 1  Re: Why Did Attorney General Loretta Lynch Ple...
# 2  BREAKING: Weiner Cooperating With FBI On Hilla...
# 3  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...
# 4  FANTASTIC! TRUMP'S 7 POINT PLAN To Reform Heal...
#
# ...

# %%
df_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12999 entries, 0 to 12998
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   uuid          12999 non-null  object
#  1   author        10575 non-null  object
#  2   published     12999 non-null  object
#  3   title         12319 non-null  object
#  4   text          12953 non-null  object
#  5   language      12999 non-null  object
#  6   crawled       12999 non-null  object
#  7   site_url      12999 non-null  object
#  8   country       12823 non-null  object
#  9   thread_title  12987 non-null  object
#  10  main_img_url  9356 non-null   object
#  11  type          12999 non-null  object
# dtypes: object(12)
# memory usage: 1.2+ MB

# %%
# dropping unnecessary column

# %%
df_cat.drop("published", axis =1, inplace = True)

# %%
df_cat.drop("crawled", axis =1, inplace = True)

# %%
df_cat.head()
# Out:
#                                        uuid                author  \
# 0  6a175f46bcd24d39b3e962ad0f29936721db70db     Barracuda Brigade
# 1  2bdc29d12605ef9cf3f09f9875040a7113be5d5b  reasoning with facts
# 2  c70e149fdd53de5e61c29281100b9de0ed268bc3     Barracuda Brigade
# 3  7cf7c15731ac2a116dd7f629bd57ea468ed70284                Fed Up
# 4  0206b54719c7e241ffe0ad4315b808290dbe6c0f                Fed Up
#
#                                                title  \
# 0  Muslims BUSTED: They Stole Millions In Gov’t B...
# 1  Re: Why Did Attorney General Loretta Lynch Ple...
# 2  BREAKING: Weiner Cooperating With FBI On Hilla...
# 3  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...
# 4  FANTASTIC! TRUMP'S 7 POINT PLAN To Reform Heal...
#
#                                                 text language  \
# 0  Print They should pay all the back all the mon...  english
# 1  Why Did Attorney General Loretta Lynch Plead T...  english
# ...

# %%
# checking the null values in the categorical column

# %%
df_cat.isnull().sum()
# Out:
# uuid               0
# author          2424
# title            680
# text              46
# language           0
# site_url           0
# country          176
# thread_title      12
# main_img_url    3643
# type               0
# dtype: int64

# %%
# checking their percentage

# %%
df_cat.isnull().sum()/len(df_cat.index)*100
# Out:
# uuid             0.000000
# author          18.647588
# title            5.231172
# text             0.353873
# language         0.000000
# site_url         0.000000
# country          1.353950
# thread_title     0.092315
# main_img_url    28.025233
# type             0.000000
# dtype: float64

# %%
# filling all the null value with unknown

# %%
clean_df=df_cat.fillna("Unknown")

# %%
# checking if it works

# %%
clean_df.isnull().sum()
# Out:
# uuid            0
# author          0
# title           0
# text            0
# language        0
# site_url        0
# country         0
# thread_title    0
# main_img_url    0
# type            0
# dtype: int64

# %%
# Identify the input and output

# %%
y=clean_df["type"]
x=clean_df.drop(columns=["type"])

# %%
# split into train and test data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# checking the shape of the split

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (10399, 9)
# (2600, 9)
# (10399,)
# (2600,)

# %%
# visualization for the x_values

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud
from nltk.corpus import stopwords
text=" ".join(x_train.loc[y_train=="fake", "title"])

word_cloud=WordCloud(stopwords=stopwords.words("english"), 
                     background_color="black",
                     width=1600, 
                     height=800).generate(text)
plt.figure(1, figsize=(30, 20))
plt.imshow(word_cloud)
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
from nltk.corpus import stopwords
text=" ".join(x_train.loc[y_train=="fake", "language"])

word_cloud=WordCloud(stopwords=stopwords.words("english"), 
                     background_color="black",
                     width=1600, 
                     height=800).generate(text)
plt.figure(1, figsize=(30, 20))
plt.imshow(word_cloud)
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
from nltk.corpus import stopwords
text=" ".join(x_train.loc[y_train=="fake", "site_url"])

word_cloud=WordCloud(stopwords=stopwords.words("english"), 
                     background_color="black",
                     width=1600, 
                     height=800).generate(text)
plt.figure(1, figsize=(30, 20))
plt.imshow(word_cloud)
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
from nltk.corpus import stopwords
text=" ".join(x_train.loc[y_train=="bs", "language"])

word_cloud=WordCloud(stopwords=stopwords.words("english"), 
                     background_color="black",
                     width=1600, 
                     height=800).generate(text)
plt.figure(1, figsize=(30, 20))
plt.imshow(word_cloud)
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
from nltk.corpus import stopwords
text=" ".join(x_train.loc[y_train=="bias", "thread_title"])

word_cloud=WordCloud(stopwords=stopwords.words("english"), 
                     background_color="black",
                     width=1600, 
                     height=800).generate(text)
plt.figure(1, figsize=(30, 20))
plt.imshow(word_cloud)
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
from nltk.corpus import stopwords
text=" ".join(x_train.loc[y_train=="fake", "main_img_url"])

word_cloud=WordCloud(stopwords=stopwords.words("english"), 
                     background_color="black",
                     width=1600, 
                     height=800).generate(text)
plt.figure(1, figsize=(30, 20))
plt.imshow(word_cloud)
plt.axis("off")
plt.show()

# %%
#x_train Data preparation

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
# initializing the inbuild stemmer
stemmer=PorterStemmer()
# using the lemmatizer
lemmatizer=WordNetLemmatizer()

# %%
def preprocess(raw_text, flag):
    # removing special characters and digit
            sentence =re.sub('[^a-zA-Z]', " ", raw_text)
    # changing sentence to loweer case
            sentence=sentence.lower()
# tokenize each words
            tokens=sentence.split()
# removiing stop words
            clean_tokens=[t for t in tokens if not t in stopwords.words("english")]
    # stemmin/lammitization
            if(flag=="stem"):
                clean_tokens = [stemmer.stem(word) for word in clean_tokens] 
            else: 
                clean_tokens=[lemmatizer.lemmatize(word) for word in clean_tokens]
            return " ".join(clean_tokens)

# %%
from tqdm import tqdm, tqdm_notebook
tqdm.pandas()

# %%
text_columns=["uuid", "author", "title", "text", "language", "site_url", "country", "thread_title", "main_img_url"]
for column in text_columns:
    x_train[column] = x_train[column].progress_apply(lambda x: preprocess(x, "stem"))
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████| 10399/10399 [00:36<00:00, 283.67it/s]

# %%
x_train.head()
# Out:
#                        uuid                                author  \
# 12558     ad ca acad bfae c  dikran arakelian norepli blogger com
# 12300      b fc c ab e f bd                           juliu hubri
# 5434    edd ab b c fb faadb                                author
# 1576      f b c dea aaa f e                               unknown
# 7983   f f c dd b c f e e e                         quintu curtiu
#
#                                                    title  \
# 12558  nasa actual record sound space hear absolut chill
# 12300                stamp licker union call post strike
# 5434     trump dump wahabbi autocrat new eastern outlook
# 1576   news democraci win volunt across countri oil s...
# 7983          fran oi de la rochefoucauld teach us cynic
#
#                                                     text language  \
# 12558  share facebook nasa space sound happen spacecr...  english
# 12300  add comment post stamp licker union call ballo...  english
# ...

# %%
# bow representation for x_train

# %%
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.feature_extraction.text import CountVectorizer

text_columns = ["title", "country", "site_url", "uuid", "main_img_url"]

transformers = [(column, CountVectorizer()) for column in text_columns]

pipeline = Pipeline([
    ('features', FeatureUnion(transformers)),
])

x_train_bow = pipeline.fit_transform(x_train)

# %%
# Get the feature names (unique words) from the pipeline
feature_names = pipeline.named_steps['features'].get_feature_names_out()

# Count the total unique words
total_unique_words = len(feature_names)

print("Total unique words:", total_unique_words)
print("Type of train features: ", type(x_train_bow))
print("shape of input data: ", x_train_bow.shape)
# Out:
# Total unique words: 45
# Type of train features:  <class 'scipy.sparse._csr.csr_matrix'>
# shape of input data:  (9, 45)

# %%
import scipy
from scipy import sparse

# %%
# alternatively
from sklearn.feature_extraction.text import CountVectorizer

text_columns = ["title", "country", "site_url", "uuid", "main_img_url"]
vectorizers = {}

for column in text_columns:
    vocab = CountVectorizer()
    x_train_bow = vocab.fit_transform(x_train[column])
    vectorizers[column] = vocab
    # You can store the transformed data in a dictionary or a new DataFrame
    if column == "title":
        x_train_bow_all = x_train_bow
    else:
        x_train_bow_all = scipy.sparse.hstack((x_train_bow_all, x_train_bow))

# %%
# pre_processing test data (x_tes)

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
# initializing the inbuild stemmer
stemmer=PorterStemmer()
# using the lemmatizer
lemmatizer=WordNetLemmatizer()

# %%
def preprocess(raw_text, flag):
    # removing special characters and digit
            sentence =re.sub('[^a-zA-Z]', " ", raw_text)
    # changing sentence to loweer case
            sentence=sentence.lower()
# tokenize each words
            tokens=sentence.split()
# removiing stop words
            clean_tokens=[t for t in tokens if not t in stopwords.words("english")]
    # stemmin/lammitization
            if(flag=="stem"):
                clean_tokens = [stemmer.stem(word) for word in clean_tokens] 
            else: 
                clean_tokens=[lemmatizer.lemmatize(word) for word in clean_tokens]
            return " ".join(clean_tokens)

# %%
from tqdm import tqdm, tqdm_notebook
tqdm.pandas()

# %%
text_columns=["uuid", "author", "title", "text", "language", "site_url", "country", "thread_title", "main_img_url"]
for column in text_columns:
    x_test[column] = x_test[column].progress_apply(lambda x: preprocess(x, "stem"))
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 2600/2600 [00:10<00:00, 236.95it/s]

# %%
x_test.head()
# Out:
#                            uuid                                author  \
# 7921           e e c b e e b ea                               unknown
# 5372       fcd f ec cb ca fd ce                               unknown
# 11388  e adedb cf f cc aa c afe                               unknown
# 6311       ae f b f ba ae f b b                             yve smith
# 12529         bf c df b e b c e  dikran arakelian norepli blogger com
#
#                                                    title  \
# 7921   civil war fbi patriot agent battl corrupt obam...
# 5372
# 11388                       top trump twitter poster ban
# 6311                         trump clear way oil pipelin
# 12529  centrum world popular multivitamin useless con...
#
#                                                     text language  \
# 7921   nov nov civil war fbi patriot agent battl corr...  english
# 5372   facebook amnesti intern human right watch repo...  russian
# ...

# %%
# bow representation of x_testfrom sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.feature_extraction.text import CountVectorizer

text_columns = ["title", "country", "site_url", "uuid", "main_img_url"]

transformers = [(column, CountVectorizer()) for column in text_columns]

pipeline = Pipeline([
    ('features', FeatureUnion(transformers)),
])

x_test_bow = pipeline.fit_transform(x_test)

# %%
# Get the feature names (unique words) from the pipeline
feature_names = pipeline.named_steps['features'].get_feature_names_out()

# Count the total unique words
total_unique_words = len(feature_names)

print("Total unique words:", total_unique_words)
print("Type of train features: ", type(x_test_bow))
print("shape of input data: ", x_test_bow.shape)
# Out:
# Total unique words: 45
# Type of train features:  <class 'scipy.sparse._csr.csr_matrix'>
# shape of input data:  (9, 45)

# %%
# machine learning path

# %%
from scipy.sparse import hstack

# %%
# %%time
x_train_bow_list = []
x_test_bow_list = []

for column in text_columns:
    vocab = CountVectorizer()
    x_train_bow = vocab.fit_transform(x_train[column])
    x_test_bow = vocab.transform(x_test[column])  # Use x_test[column] instead of x_test
    x_train_bow_list.append(x_train_bow)
    x_test_bow_list.append(x_test_bow)

x_train_bow = hstack(x_train_bow_list)
x_test_bow = hstack(x_test_bow_list)

# Check the shapes
print(x_train_bow.shape)
print(y_train.shape)
print(x_test_bow.shape)
print(y_test.shape)
classifier = MultinomialNB()
classifier.fit(x_train_bow, y_train)
y_test_pred1 = classifier.predict(x_test_bow)

# Evaluate the model
accuracy = metrics.accuracy_score(y_test, y_test_pred)
print("Accuracy:", accuracy)
# Out:
# (10399, 21255)
# (10399,)
# (2600, 21255)
# (2600,)
# Accuracy: 0.941923076923077
# CPU times: total: 1.45 s
# Wall time: 3.11 s

# %%
# evaluating of the model

# %%
conf_matrix = metrics.confusion_matrix(y_test, y_test_pred)
print(conf_matrix)
# Out:
# [[  57   31    0    0    0    0    0    0]
#  [   0 2299    0    0    0    0    0    0]
#  [   0   58   31    0    0    0    0    0]
#  [   0    3    0    0    0    0    0    0]
#  [   0   24    0    0   20    0    0    0]
#  [   4   12    0    0    0    6    0    0]
#  [   0   15    0    0    0    0   13    0]
#  [   0    4    0    0    0    0    0   23]]

# %%
sns.heatmap(conf_matrix, annot=True, fmt='d')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# Class Imbalance:
#
# Class 1 has a very large number of samples (2299 true instances), while other classes have significantly fewer (some in the tens).
#
# This imbalance likely skews the model’s learning and performance.
#
# Class 1 is predicted very well:
#
# Out of 2299 instances of class 1, the model predicted almost all correctly with very few misclassifications.
#
# This might be because of the large amount of training data for class 1.
#
# Class Confusions:
#
# Class 0: 57 correct, but 31 misclassified as class 1.
#
# Class 2: 31 misclassified as class 1, and 58 correctly classified.
#
# Classes 3–7: Low numbers overall, but considerable confusion:
#
# Class 4: misclassified as 1 and 5.
#
# Class 5: misclassified mostly as class 1.
#
# Class 6: half misclassified as class 1.
#
# Class 7: some misclassified as class 1.
#
# Model Bias:
#
# The model heavily predicts class 1, especially when it’s unsure. This is a common issue with class imbalance.

# %%
# print(metrics.classification_report(y_test, y_test_pred))

# %%
# trying other model

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')

# %%
# training and  predicting

# %%
classifier.fit(x_train_bow, y_train)
y_test_pred = classifier.predict(x_test_bow)

# %%
# evaluating matrix

# %%
sns.histplot(y_test, color="blue", alpha=0.5, bins=5)
sns.histplot(y_test_pred, color="red", alpha=0.5, bins=5)
plt.show()

# %%
from sklearn import metrics

print("Accuracy:", metrics.accuracy_score(y_test, y_test_pred))
print(metrics.classification_report(y_test, y_test_pred))

# Confusion Matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = metrics.confusion_matrix(y_test, y_test_pred)
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Random Forest")
plt.show()
# Out:
# Accuracy: 0.9892307692307692
# C:\Users\Bn Maliq\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Bn Maliq\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Bn Maliq\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# f1-score

# %%
from sklearn.metrics import classification_report

# Replace `y_test` and `y_pred` with your actual variable names if different
# y_test: true labels
# y_pred: predicted labels

print("Classification Report (includes precision, recall, and F1-score):")
print(classification_report(y_test, y_test_pred, digits=3))
# Out:
# Classification Report (includes precision, recall, and F1-score):
# C:\Users\Bn Maliq\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Bn Maliq\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Bn Maliq\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# The model is a multi-class classifier trained on a highly imbalanced dataset with 8 distinct classes (labeled 0–7). The class distribution is significantly skewed, with Class 1 containing the overwhelming majority of instances, while others have very few.
#
# Confusion Matrix Analysis
# From the confusion matrix:
#
# Class 1 (majority class) is predicted with extremely high accuracy (100% recall).
#
# Most misclassifications occur when minority class instances are incorrectly labeled as Class 1, indicating a strong bias toward the dominant class.
#
# Some classes (e.g., Class 3 and Class 4) are completely ignored by the model — not a single correct prediction was made for them.
#
# F1-Score Insights
# Using the classification_report, the model’s per-class performance is summarized as follows:
#
# Strong Performance:
# Class 1: F1-score = 0.969
#
# Class 7: F1-score = 0.920
#
# Moderate Performance:
# Class 0: F1-score = 0.765
#
# Class 6: F1-score = 0.634
#
# Class 2: F1-score = 0.517
#
# Overall Scores:
# Accuracy: 93.4%
#
# Macro F1-score: 0.507 (treats all classes equally)
#
# Weighted F1-score: 0.919 (accounts for class imbalance)
